# %%
#imports needed
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import os

# %%
# python environment
# python==3.12.0
# matplotlib == 3.8.3
# numpy == 1.26.4
# !conda list
# Out:
# # packages in environment at C:\Users\Corey\anaconda3\envs\panalysis:
# #
# # Name                    Version                   Build  Channel
# anyio                     4.3.0                    pypi_0    pypi
# argon2-cffi               23.1.0                   pypi_0    pypi
# argon2-cffi-bindings      21.2.0                   pypi_0    pypi
# arrow                     1.3.0                    pypi_0    pypi
# asttokens                 2.4.1                    pypi_0    pypi
# async-lru                 2.0.4                    pypi_0    pypi
# attrs                     23.2.0                   pypi_0    pypi
# babel                     2.14.0                   pypi_0    pypi
# beautifulsoup4            4.12.3                   pypi_0    pypi
# bleach                    6.1.0                    pypi_0    pypi
# bzip2                     1.0.8                h2bbff1b_5
# ca-certificates           2024.3.11            haa95532_0
# certifi                   2024.2.2                 pypi_0    pypi
# cffi                      1.16.0                   pypi_0    pypi
# charset-normalizer        3.3.2                    pypi_0    pypi
# colorama                  0.4.6                    pypi_0    pypi
# comm                      0.2.2                    pypi_0    pypi
# contourpy                 1.2.1                    pypi_0    pypi
# cycler                    0.12.1                   pypi_0    pypi
# debugpy                   1.8.1                    pypi_0    pypi
# decorator                 5.1.1                    pypi_0    pypi
# defusedxml                0.7.1                    pypi_0    pypi
# executing                 2.0.1                    pypi_0    pypi
# expat                     2.5.0                hd77b12b_0
# fastjsonschema            2.19.1                   pypi_0    pypi
# fonttools                 4.50.0                   pypi_0    pypi
# fqdn                      1.5.1                    pypi_0    pypi
# h11                       0.14.0                   pypi_0    pypi
# httpcore                  1.0.5                    pypi_0    pypi
# httpx                     0.27.0                   pypi_0    pypi
# idna                      3.6                      pypi_0    pypi
# ipykernel                 6.29.4                   pypi_0    pypi
# ipython                   8.23.0                   pypi_0    pypi
# ipywidgets                8.1.2                    pypi_0    pypi
# isoduration               20.11.0                  pypi_0    pypi
# jedi                      0.19.1                   pypi_0    pypi
# jinja2                    3.1.3                    pypi_0    pypi
# json5                     0.9.24                   pypi_0    pypi
# jsonpointer               2.4                      pypi_0    pypi
# jsonschema                4.21.1                   pypi_0    pypi
# jsonschema-specifications 2023.12.1                pypi_0    pypi
# jupyter                   1.0.0                    pypi_0    pypi
# jupyter-client            8.6.1                    pypi_0    pypi
# jupyter-console           6.6.3                    pypi_0    pypi
# jupyter-core              5.7.2                    pypi_0    pypi
# jupyter-events            0.10.0                   pypi_0    pypi
# jupyter-lsp               2.2.4                    pypi_0    pypi
# jupyter-server            2.13.0                   pypi_0    pypi
# jupyter-server-terminals  0.5.3                    pypi_0    pypi
# jupyterlab                4.1.5                    pypi_0    pypi
# jupyterlab-pygments       0.3.0                    pypi_0    pypi
# jupyterlab-server         2.25.4                   pypi_0    pypi
# jupyterlab-widgets        3.0.10                   pypi_0    pypi
# kiwisolver                1.4.5                    pypi_0    pypi
# libffi                    3.4.4                hd77b12b_0
# markupsafe                2.1.5                    pypi_0    pypi
# matplotlib                3.8.3                    pypi_0    pypi
# matplotlib-inline         0.1.6                    pypi_0    pypi
# mistune                   3.0.2                    pypi_0    pypi
# nbclient                  0.10.0                   pypi_0    pypi
# nbconvert                 7.16.3                   pypi_0    pypi
# nbformat                  5.10.3                   pypi_0    pypi
# nest-asyncio              1.6.0                    pypi_0    pypi
# notebook                  7.1.2                    pypi_0    pypi
# notebook-shim             0.2.4                    pypi_0    pypi
# numpy                     1.26.4                   pypi_0    pypi
# openssl                   3.0.13               h2bbff1b_0
# overrides                 7.7.0                    pypi_0    pypi
# packaging                 24.0                     pypi_0    pypi
# pandas                    2.2.1                    pypi_0    pypi
# pandocfilters             1.5.1                    pypi_0    pypi
# parso                     0.8.3                    pypi_0    pypi
# pillow                    10.3.0                   pypi_0    pypi
# pip                       23.3.1          py312haa95532_0
# platformdirs              4.2.0                    pypi_0    pypi
# prometheus-client         0.20.0                   pypi_0    pypi
# prompt-toolkit            3.0.43                   pypi_0    pypi
# psutil                    5.9.8                    pypi_0    pypi
# pure-eval                 0.2.2                    pypi_0    pypi
# pycparser                 2.22                     pypi_0    pypi
# pygments                  2.17.2                   pypi_0    pypi
# pyparsing                 3.1.2                    pypi_0    pypi
# python                    3.12.0               h1d929f7_0
# python-dateutil           2.9.0.post0              pypi_0    pypi
# python-json-logger        2.0.7                    pypi_0    pypi
# pytz                      2024.1                   pypi_0    pypi
# pywin32                   306                      pypi_0    pypi
# pywinpty                  2.0.13                   pypi_0    pypi
# pyyaml                    6.0.1                    pypi_0    pypi
# pyzmq                     25.1.2                   pypi_0    pypi
# qtconsole                 5.5.1                    pypi_0    pypi
# qtpy                      2.4.1                    pypi_0    pypi
# referencing               0.34.0                   pypi_0    pypi
# requests                  2.31.0                   pypi_0    pypi
# rfc3339-validator         0.1.4                    pypi_0    pypi
# rfc3986-validator         0.1.1                    pypi_0    pypi
# rpds-py                   0.18.0                   pypi_0    pypi
# send2trash                1.8.2                    pypi_0    pypi
# setuptools                68.2.2          py312haa95532_0
# six                       1.16.0                   pypi_0    pypi
# sniffio                   1.3.1                    pypi_0    pypi
# soupsieve                 2.5                      pypi_0    pypi
# sqlite                    3.41.2               h2bbff1b_0
# stack-data                0.6.3                    pypi_0    pypi
# terminado                 0.18.1                   pypi_0    pypi
# tinycss2                  1.2.1                    pypi_0    pypi
# tk                        8.6.12               h2bbff1b_0
# tornado                   6.4                      pypi_0    pypi
# traitlets                 5.14.2                   pypi_0    pypi
# types-python-dateutil     2.9.0.20240316           pypi_0    pypi
# tzdata                    2024.1                   pypi_0    pypi
# uri-template              1.3.0                    pypi_0    pypi
# urllib3                   2.2.1                    pypi_0    pypi
# vc                        14.2                 h21ff451_1
# vs2015_runtime            14.27.29016          h5e58377_2
# wcwidth                   0.2.13                   pypi_0    pypi
# webcolors                 1.13                     pypi_0    pypi
# webencodings              0.5.1                    pypi_0    pypi
# websocket-client          1.7.0                    pypi_0    pypi
# wheel                     0.41.2          py312haa95532_0
# widgetsnbextension        4.0.10                   pypi_0    pypi
# xz                        5.4.6                h8cc25b3_0
# zlib                      1.2.13               h8cc25b3_0

# %%
#getting the data for Miller and Ross 
cwd = os.getcwd()
datadir = os.path.join(cwd, 'data')

# %%
#setting the path for the 
miller = os.path.join(datadir, "alanmiller.csv")
ross = os.path.join(datadir, "jeanaross.csv")

# %%
#load the data for Miller and Ross 
Millerdf = pd.read_csv(miller)
Rossdf = pd.read_csv(ross)

# %%
Millerdf.head() #looking at both datasets to see whats inside
# Out:
#              FilingDate    Contributor         CityState ZipCode  \
# 0  3/4/2024 11:14:59 PM  GREG SCOFIELD  GUNTERSVILLE, AL   35976
# 1  3/4/2024 11:14:59 PM            NaN               NaN     NaN
# 2  3/4/2024 11:14:59 PM            NaN               NaN     NaN
# 3  3/4/2024 11:14:59 PM            NaN               NaN     NaN
# 4  3/4/2024 11:14:59 PM   ROGER MILLER         JOPPA, AL   35087
#
#   ContributorType  Amount       ContributionDate     ContributionType  \
# 0      Individual   200.0  1/26/2024 12:00:00 AM      Cash (Itemized)
# 1             NaN   100.0   2/5/2024 12:00:00 AM  Cash (Non-Itemized)
# 2             NaN    25.0   2/5/2024 12:00:00 AM  Cash (Non-Itemized)
# 3             NaN   100.0   2/7/2024 12:00:00 AM  Cash (Non-Itemized)
# 4      Individual   500.0   2/7/2024 12:00:00 AM      Cash (Itemized)
#
#   Description        RecipientName  ContributionID  RecipeintOrgID  ContSeqID  \
# 0         NaN  ALAN CLIFTON MILLER         1114323           31117     860906
# 1         NaN  ALAN CLIFTON MILLER         1114325           31117     860907
# 2         NaN  ALAN CLIFTON MILLER         1114327           31117     860908
# 3         NaN  ALAN CLIFTON MILLER         1114329           31117     860909
# 4         NaN  ALAN CLIFTON MILLER         1114331           31117     860910
#
#    MAXROWS  RecordCount
# 0    20000          674
# 1    20000          674
# 2    20000          674
# 3    20000          674
# 4    20000          674

# %%
Rossdf.head()
# Out:
#              FilingDate     Contributor       CityState ZipCode  \
# 0  3/19/2024 9:41:31 AM   DANIEL ROSSER   TUSCUMBIA, AL   35674
# 1  12/7/2021 8:38:39 AM  DEREK W ROSSON  RAINSVILLE, AL   35986
# 2   2/1/2022 8:07:22 AM  DEREK W ROSSON  RAINSVILLE, AL   35986
# 3   2/1/2022 8:07:22 AM  DEREK W ROSSON  RAINSVILLE, AL   35986
# 4   2/1/2022 8:07:22 AM  DEREK W ROSSON  RAINSVILLE, AL   35986
#
#   ContributorType   Amount        ContributionDate    ContributionType  \
# 0      Individual  1620.00  10/17/2023 12:00:00 AM  In-Kind (Itemized)
# 1      Individual  1776.70  11/23/2021 12:00:00 AM  In-Kind (Itemized)
# 2      Individual   400.00    1/3/2022 12:00:00 AM     Cash (Itemized)
# 3      Individual  1000.00   1/11/2022 12:00:00 AM     Cash (Itemized)
# 4      Individual   455.04    1/4/2022 12:00:00 AM  In-Kind (Itemized)
#
#   Description              RecipientName  ContributionID  RecipeintOrgID  \
# 0         NaN  CHARLES DANIEL ROSSER JR.         1115702           30579
# 1         NaN         DEREK WAYNE ROSSON          839297           29525
# 2         NaN         DEREK WAYNE ROSSON          859332           29525
# 3         NaN         DEREK WAYNE ROSSON          859333           29525
# 4         NaN         DEREK WAYNE ROSSON          859334           29525
#
#    ContSeqID  MAXROWS  RecordCount
# 0     862077    20000          395
# 1     662644    20000          395
# 2     681501    20000          395
# 3     681502    20000          395
# 4     681503    20000          395

# %%
#lets clean up the dataframe to get only the contributions where miller and ross are reciving the money
Millerdf[Millerdf['RecipientName'] == 'ALAN CLIFTON MILLER']['Amount'].sum()
# Out:
# 14308.45

# %% [markdown]
# As of 4/3/2024 this is the correct value for Alan Miller. Lets do the same for Jeana Ross and put these two datasets into their own dataframe.

# %%
#lets clean up the dataframe to get only the contributions where miller and ross are reciving the money
Rossdf[Rossdf['RecipientName'] == 'JEANA ROSS']['Amount'].sum()
# Out:
# 104844.20999999999

# %% [markdown]
# As of 4/3/2024 this is the correct value for Jeana Ross.

# %%
# cleaning the data to just get the datafame that has Jeana and Alan without any other people 
cleanrossdf = Rossdf[Rossdf['RecipientName'] == 'JEANA ROSS']
cleanmillerdf = Millerdf[Millerdf['RecipientName'] == 'ALAN CLIFTON MILLER']

# %%
# what are the unique contributor types? 
cleanrossdf['ContributorType'].unique() #the types of contributions
# Out:
# array(['Individual', 'Group/Business/Corporation', 'PAC', nan],
#       dtype=object)

# %%
cleanmillerdf['ContributorType'].unique()
# Out:
# array(['Individual', nan, 'Group/Business/Corporation'], dtype=object)

# %%
#lets ask the question, what PACS contributed to each campaign and how much as of 4/3/2024?
pacsross = cleanrossdf[cleanrossdf['ContributorType'] == 'PAC'].sort_values(by='Amount', ascending=False)

# %%
pacsmiller = cleanmillerdf[cleanmillerdf['ContributorType'] == 'PAC'].sort_values(by='Amount', ascending=False)

# %%
pacsmiller #this is empty... Interesting. This means he has no PAC money.
# Out:
# Empty DataFrame
# Columns: [FilingDate, Contributor, CityState, ZipCode, ContributorType, Amount, ContributionDate, ContributionType, Description, RecipientName, ContributionID, RecipeintOrgID, ContSeqID, MAXROWS, RecordCount]
# Index: []

# %%
cleanmillerdf.to_csv("data/cleandata/Alan_Miller_Contributions.csv")
cleanrossdf.to_csv("data/cleandata/Jeana_Ross_Contributions.csv")

# %% [markdown]
# There were no political action committees that contributed to Miller's campaign as of 4/3/2024. However, there were 2 "Group/Business/Corporation" ContributorType in his data. There was one buisness contribution from Union Grove and one from Birmingham. Ross recieved 13 contributions from PACs, 12 of which has the CityState category of "MONTGOMERY, AL." However, there are two Montgomery contributions that are at the same time stamp and same contributor, but have differing amounts. For example, BIPAC gave 10000.0 and 5000.0 contributions on 3/1/2024 but they are listed as seperate transactions. Therefore, there are 13 pac contributions, but 11 come from Montgomery.

# %%
pacsross
# Out:
#                FilingDate                                        Contributor  \
# 64    3/1/2024 5:36:46 PM                                              BIPAC
# 122  4/1/2024 11:02:26 AM                                           FARM PAC
# 63    3/1/2024 5:36:46 PM                                              BIPAC
# 66    3/1/2024 5:36:46 PM                                       PROGRESS PAC
# 108  3/16/2024 8:33:19 AM                                             ALAPAC
# 112  3/25/2024 9:02:43 AM        TRUST REPRESENTING INVOLVED ALABAMA LAWYERS
# 117   4/1/2024 9:34:19 AM                                            CAREPAC
# 120   4/1/2024 9:34:19 AM        ALABAMA BUILDERS POLITICAL ACTION COMMITTEE
# 121  4/1/2024 11:02:26 AM        ALABAMA REALTORS POLITICAL ACTION COMMITTEE
# 68    3/1/2024 5:36:46 PM    STATE FARM AGENTS AND ASSOCIATES OF ALABAMA PAC
# 107  3/16/2024 8:33:19 AM  ALABAMA PHARMACY ASSOCIATION POLITICAL ACTION ...
# 109  3/16/2024 8:33:19 AM                                           SV&B PAC
# 118   4/1/2024 9:34:19 AM                                          BIG I PAC
# 123  4/1/2024 11:02:26 AM                                               AWBA
#
#           CityState ZipCode ContributorType   Amount       ContributionDate  \
# 64   MONTGOMERY, AL   36101             PAC  10000.0   2/5/2024 12:00:00 AM
# 122  MONTGOMERY, AL   36191             PAC   7500.0   4/1/2024 12:00:00 AM
# 63   MONTGOMERY, AL   36101             PAC   5000.0   2/5/2024 12:00:00 AM
# 66   MONTGOMERY, AL   36102             PAC   5000.0  2/20/2024 12:00:00 AM
# 108  MONTGOMERY, AL   36101             PAC   5000.0  3/14/2024 12:00:00 AM
# 112  MONTGOMERY, AL   36101             PAC   5000.0  3/21/2024 12:00:00 AM
# 117  MONTGOMERY, AL   36123             PAC   5000.0  3/21/2024 12:00:00 AM
# 120  MONTGOMERY, AL   36124             PAC   2500.0  3/20/2024 12:00:00 AM
# 121  MONTGOMERY, AL   36104             PAC   2500.0   4/1/2024 12:00:00 AM
# 68   TUSCALOOSA, AL   35406             PAC   1000.0   2/2/2024 12:00:00 AM
# 107  MONTGOMERY, AL   36106             PAC   1000.0  3/14/2024 12:00:00 AM
# 109  MONTGOMERY, AL   36104             PAC   1000.0  3/14/2024 12:00:00 AM
# 118  BIRMINGHAM, AL   35211             PAC   1000.0  3/15/2024 12:00:00 AM
# 123  MONTGOMERY, AL   36104             PAC   1000.0   4/1/2024 12:00:00 AM
#
#     ContributionType Description RecipientName  ContributionID  \
# 64   Cash (Itemized)         NaN    JEANA ROSS         1108206
# 122  Cash (Itemized)         NaN    JEANA ROSS         1118749
# 63   Cash (Itemized)         NaN    JEANA ROSS         1108205
# 66   Cash (Itemized)         NaN    JEANA ROSS         1111734
# 108  Cash (Itemized)         NaN    JEANA ROSS         1115351
# 112  Cash (Itemized)         NaN    JEANA ROSS         1115910
# 117  Cash (Itemized)         NaN    JEANA ROSS         1118449
# 120  Cash (Itemized)         NaN    JEANA ROSS         1118452
# 121  Cash (Itemized)         NaN    JEANA ROSS         1118748
# 68   Cash (Itemized)         NaN    JEANA ROSS         1111736
# 107  Cash (Itemized)         NaN    JEANA ROSS         1115350
# 109  Cash (Itemized)         NaN    JEANA ROSS         1115352
# 118  Cash (Itemized)         NaN    JEANA ROSS         1118450
# 123  Cash (Itemized)         NaN    JEANA ROSS         1118750
#
#      RecipeintOrgID  ContSeqID  MAXROWS  RecordCount
# 64            31125     858690    20000          395
# 122           31125     863763    20000          395
# 63            31125     858689    20000          395
# 66            31125     858692    20000          395
# 108           31125     861716    20000          395
# 112           31125     862263    20000          395
# 117           31125     863637    20000          395
# 120           31125     863640    20000          395
# 121           31125     863762    20000          395
# 68            31125     858694    20000          395
# 107           31125     861715    20000          395
# 109           31125     861717    20000          395
# 118           31125     863638    20000          395
# 123           31125     863764    20000          395

# %%
#lets plot Jeana Ross contributions by Pac and City/State
groupedross = pacsross.groupby(['Contributor', 'CityState']).sum().reset_index().sort_values(by='Amount', ascending=False)

# %%
pd.set_option('display.max_colwidth', None)
groupedross[['Contributor', 'CityState', 'Amount']].reset_index(drop='index')
# Out:
#                                                 Contributor       CityState  \
# 0                                                     BIPAC  MONTGOMERY, AL
# 1                                                  FARM PAC  MONTGOMERY, AL
# 2                                                    ALAPAC  MONTGOMERY, AL
# 3                                                   CAREPAC  MONTGOMERY, AL
# 4                                              PROGRESS PAC  MONTGOMERY, AL
# 5               TRUST REPRESENTING INVOLVED ALABAMA LAWYERS  MONTGOMERY, AL
# 6               ALABAMA BUILDERS POLITICAL ACTION COMMITTEE  MONTGOMERY, AL
# 7               ALABAMA REALTORS POLITICAL ACTION COMMITTEE  MONTGOMERY, AL
# 8   ALABAMA PHARMACY ASSOCIATION POLITICAL ACTION COMMITTEE  MONTGOMERY, AL
# 9                                                      AWBA  MONTGOMERY, AL
# 10                                                BIG I PAC  BIRMINGHAM, AL
# 11          STATE FARM AGENTS AND ASSOCIATES OF ALABAMA PAC  TUSCALOOSA, AL
# 12                                                 SV&B PAC  MONTGOMERY, AL
#
#      Amount
# 0   15000.0
# 1    7500.0
# 2    5000.0
# 3    5000.0
# 4    5000.0
# 5    5000.0
# 6    2500.0
# 7    2500.0
# 8    1000.0
# 9    1000.0
# 10   1000.0
# 11   1000.0
# 12   1000.0

# %%
#lets create a list of locations and pacnames for plotting purposes
locationsross = list(groupedross['CityState']) #where the pacs originate in order by amount
pacname = list(groupedross['Contributor']) #the pac name in order by amount

# %%
locationsross #locations in order by amount of where Ross got PAC money
# Out:
# ['MONTGOMERY, AL',
#  'MONTGOMERY, AL',
#  'MONTGOMERY, AL',
#  'MONTGOMERY, AL',
#  'MONTGOMERY, AL',
#  'MONTGOMERY, AL',
#  'MONTGOMERY, AL',
#  'MONTGOMERY, AL',
#  'MONTGOMERY, AL',
#  'MONTGOMERY, AL',
#  'BIRMINGHAM, AL',
#  'TUSCALOOSA, AL',
#  'MONTGOMERY, AL']

# %%
#creating a color for each bar and storing in a list
jeanacolors = {'MONTGOMERY, AL':'red', 'BIRMINGHAM, AL': 'green', 'TUSCALOOSA, AL': 'orange'} #assigning colors by town
jeanabarcolors = [jeanacolors.get(i) for i in locationsross] #creating list of colors to plot by

# %%
jeanabarcolors
# Out:
# ['red',
#  'red',
#  'red',
#  'red',
#  'red',
#  'red',
#  'red',
#  'red',
#  'red',
#  'red',
#  'green',
#  'orange',
#  'red']

# %%
cleanpacname = ['BIPAC', #I am making some of the names shorter for the plot and putting a star beside those that were changed.  
 'FARM PAC',
 'ALAPAC',
 'CAREPAC',
 'PROGRESS PAC',
 'TRIALS*',
 'AL Builders PAC*',
 'AL Realtors PAC*',
 'AL PA PAC*',
 'AWBA',
 'BIG I PAC',
 'SFAAA OF AL PAC*',
 'SV&B PAC']

# %%
#creating a legend element that can be used for the plot
from matplotlib.patches import Patch
legend_elements = [Patch(facecolor=color, edgecolor='black', label=location) for location, color in jeanacolors.items()]

# %%
#plot it all
fig, ax = plt.subplots(figsize=(9, 5))
ax.bar(range(len(groupedross)), groupedross['Amount'], color=jeanabarcolors)
ax.set_ylabel('Contributions in Dollars ($)')
ax.set_xlabel('PAC Name')
ax.set_title('Contributions to Jeana Ross by Political Action Committee (PAC) and Location')
ax.set_xticks(range(len(pacname)), cleanpacname, rotation=25, ha='right')
ax.legend(handles=legend_elements, loc='center right', bbox_to_anchor=(1, 0.5))

#ax[1].bar(range(len(businessmiller)), businessmiller['Amount'], color=  , rotation=90)

# %%
#now we will plot the contributions by type
groupedross = cleanrossdf.groupby(['ContributorType'], dropna=False)['Amount'].sum().reset_index().sort_values(by='Amount', ascending=False)

# %%
groupedross['ContributorType'] = groupedross['ContributorType'].astype(str)

# %%
groupedross
# Out:
#               ContributorType    Amount
# 2                         PAC  52500.00
# 1                  Individual  45949.21
# 0  Group/Business/Corporation   6245.00
# 3                         nan    150.00

# %%
groupedross['ContributorType'].replace('nan', 'Not Itemized', inplace=True)
# Out:
# C:\Users\Corey\AppData\Local\Temp\ipykernel_14784\1323817266.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   groupedross['ContributorType'].replace('nan', 'Not Itemized', inplace=True)

# %%
contributorcolors = {'PAC':'Red', 'Group/Business/Corporation':'Blue', 'Individual':'Green', 'Not Itemized':'Yellow'}
rosscolors = [contributorcolors.get(str(i)) for i in groupedross['ContributorType']]

# %%
rosscontributions = list(groupedross['ContributorType'])

# %%
rosscolors
# Out:
# ['Red', 'Green', 'Blue', 'Yellow']

# %%
groupedmiller = cleanmillerdf.groupby(['ContributorType'], dropna=False)['Amount'].sum().reset_index().sort_values(by='Amount', ascending=False)

# %%
groupedmiller['ContributorType'] = groupedmiller['ContributorType'].astype(str)

# %%
groupedmiller['ContributorType'].replace('nan', 'Not Itemized', inplace=True)
# Out:
# C:\Users\Corey\AppData\Local\Temp\ipykernel_14784\4177064833.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   groupedmiller['ContributorType'].replace('nan', 'Not Itemized', inplace=True)

# %%
#now we will add PAC donations to millers dataframe to make the data more understandable 
# he has 0 dollars in pac contributions
groupedmiller.loc[len(groupedmiller.index)] = ['PAC', 0.00]
millercolors = [contributorcolors.get(str(i)) for i in groupedmiller['ContributorType']]

# %%
groupedmiller
# Out:
#               ContributorType    Amount
# 1                  Individual  11325.00
# 2                Not Itemized   1983.45
# 0  Group/Business/Corporation   1000.00
# 3                         PAC      0.00

# %%
#Adding colors so that it sorts correctly 
groupedmiller['PlotColors']=millercolors
groupedross['PlotColors']=rosscolors

# %%
#now sort by PAC, Individual, Business, and Not Itemized
custom_dict = {'PAC': 0, 'Individual': 1, 'Group/Business/Corporation': 3, 'Not Itemized': 4}
groupedmiller.sort_values(by=['ContributorType'], key=lambda x: x.map(custom_dict), inplace=True)
groupedross.sort_values(by=['ContributorType'], key=lambda x: x.map(custom_dict), inplace=True)

# %%
millercontributions = list(groupedmiller['ContributorType']) #putting final contributor list in for Miller

# %%
rosscolors = list(groupedross['PlotColors'])
millercolors = list(groupedmiller['PlotColors'])
fig, ax = plt.subplots(figsize=(6, 5*2), nrows=2)
ross = ax[0].bar(groupedross['ContributorType'], groupedross['Amount'], color=rosscolors)
ax[0].set_xticks(range(len(rosscontributions)), rosscontributions, rotation=40)
miller = ax[1].bar(groupedmiller['ContributorType'], groupedmiller['Amount'], color=millercolors)
ax[1].set_xticks(range(len(millercontributions)), millercontributions, rotation=40)
ax[0].set_title('Jeana Ross Campaign Contributions by Type')
ax[1].set_title('Alan Miller Campaign Contributions by Type')
ax[0].set_ylabel('Contributions in Dollars ($)')
ax[1].set_ylabel('Contributions in Dollars ($)')
for p in ross:
   height = p.get_height()
   ax[0].annotate('{}'.format(height),
      xy=(p.get_x() + p.get_width() / 2, height),
      xytext=(0, 3), # 3 points vertical offset
      textcoords="offset points",
      ha='center', va='bottom')

for p in miller:
   height = p.get_height()
   ax[1].annotate('{}'.format(height),
      xy=(p.get_x() + p.get_width() / 2, height),
      xytext=(0, 3), # 3 points vertical offset
      textcoords="offset points",
      ha='center', va='bottom')

ax[0].set_ylim(0, 60000)
ax[1].set_ylim(0, 60000)
fig.subplots_adjust(hspace=0.8)

# %% [markdown]
# Looks like there were signifigant differences between the individual contributions between Alan Miller and Jeana Ross. However, it is not clear why the individual contributions were different. Lets plot by contributor and contribution type.

# %%
#now we will create summary plots for each of the campaigns that can show contributor and contributor types
contributionsross = cleanrossdf.groupby(['ContributorType', 'ContributionType'], dropna=False)['Amount'].sum()

# Convert contributionsross to DataFrame for easy plotting
contributions_df = contributionsross.unstack()
desired_order = ['PAC', 'Individual', 'Group/Business/Corporation', np.nan]
contributions_df = contributions_df.loc[desired_order]

# Define colors for each contribution type
colors = {'Cash (Itemized)': 'Green', 'Cash (Non-Itemized)':'lawngreen', 'In-Kind (Itemized)': 'blue', 'Loan': 'Red'}
colors = [colors.get(x) for x in contributions_df.columns]
# Plotting with specific colors
bars = contributions_df.plot(kind='bar', stacked=True, color=colors)

plt.title('Contribution Type by Contributor for Jeana Ross Campaign')
plt.xlabel('Contributor')
plt.ylabel('Contribution Value ($)')
# Set y-axis limits
plt.ylim(0, 60000)
plt.legend(loc='upper right', title='Contribution Type')
plt.xticks(rotation=40, ha='right')
plt.show()

# %%
#making a table readout
contributionsross = cleanrossdf.groupby(['ContributorType', 'ContributionType'], dropna=False)['Amount'].sum()

# Convert contributionsross to DataFrame for easy plotting
contributions_df = contributionsross.unstack()
desired_order = ['PAC', 'Individual', 'Group/Business/Corporation', np.nan]
contributions_df = contributions_df.loc[desired_order]
contributions_df.stack()
# Out:
# ContributorType             ContributionType
# PAC                         Cash (Itemized)        52500.00
# Individual                  Cash (Itemized)        33675.00
#                             In-Kind (Itemized)      1040.00
#                             Loan                   11234.21
# Group/Business/Corporation  Cash (Itemized)         6245.00
# NaN                         Cash (Non-Itemized)      150.00
# dtype: float64

# %%
desired_order = ['PAC', 'Group/Business/Corporation', 'Individual', np.nan]
contributions_df = contributions_df.loc[desired_order]
contributions_df
# Out:
# ContributionType            Cash (Itemized)  Cash (Non-Itemized)  \
# ContributorType
# PAC                                 52500.0                  NaN
# Group/Business/Corporation           6245.0                  NaN
# Individual                          33675.0                  NaN
# NaN                                     NaN                150.0
#
# ContributionType            In-Kind (Itemized)      Loan
# ContributorType
# PAC                                        NaN       NaN
# Group/Business/Corporation                 NaN       NaN
# Individual                              1040.0  11234.21
# NaN                                        NaN       NaN

# %%
#what was the loan amount and when?
cleanrossdf[cleanrossdf['ContributionType']=='Loan']
# Out:
#               FilingDate   Contributor         CityState ZipCode  \
# 50  2/1/2024 11:06:40 AM  JEANA A ROSS  GUNTERSVILLE, AL   35976
# 52  2/1/2024 11:06:40 AM  JEANA A ROSS  GUNTERSVILLE, AL   35976
#
#    ContributorType    Amount       ContributionDate ContributionType  \
# 50      Individual  10000.00  1/31/2024 12:00:00 AM             Loan
# 52      Individual   1234.21  1/29/2024 12:00:00 AM             Loan
#
#    Description RecipientName  ContributionID  RecipeintOrgID  ContSeqID  \
# 50         NaN    JEANA ROSS         1085352           31125     844179
# 52         NaN    JEANA ROSS         1085424           31125     844181
#
#     MAXROWS  RecordCount
# 50    20000          395
# 52    20000          395

# %%
contributionsmiller = cleanmillerdf.groupby(['ContributorType', 'ContributionType'], dropna=False)['Amount'].sum()

# Convert contributionsross to DataFrame for easy plotting
contributions_df = contributionsmiller.unstack()
contributions_df.loc['PAC'] = np.nan #adding nan for 0 in PAC money for comparison
desired_order = ['PAC', 'Individual', 'Group/Business/Corporation', np.nan]
contributions_df = contributions_df.loc[desired_order]

# Define colors for each contribution type
colors = {'Cash (Itemized)': 'Green', 'Cash (Non-Itemized)':'lawngreen', 'In-Kind (Itemized)': 'Orange', 'Loan': 'Red'}
colors = [colors.get(x) for x in contributions_df.columns]
# Plotting with specific colors
bars = contributions_df.plot(kind='bar', stacked=True, color=colors)

plt.title('Contribution Type by Contributor for Alan Miller Campaign')
plt.xlabel('Contributor')
plt.ylabel('Contribution Value ($)')
# Set y-axis limits
plt.ylim(0, 60000)
plt.legend(loc='upper right', title='Contribution Type')
plt.xticks(rotation=40, ha='right')
plt.show()

# %% [markdown]
# From the two plots, Jeana got more in individual cash contributions, but had a larger loan. There is also a donation marked as an "Individual (In-Kind Itemized)" donation, it looks like.

# %%
#making a table for readout
contributionsmiller = cleanmillerdf.groupby(['ContributorType', 'ContributionType'], dropna=False)['Amount'].sum()
# Convert contributionsross to DataFrame for easy plotting
contributions_df = contributionsmiller.unstack()
contributions_df.loc['PAC'] = np.nan #adding nan for 0 in PAC money for comparison
desired_order = ['PAC', 'Individual', 'Group/Business/Corporation', np.nan]
contributions_df = contributions_df.loc[desired_order]
contributions_df.stack()
# Out:
# ContributorType             ContributionType
# Individual                  Cash (Itemized)        10075.00
#                             Loan                    1250.00
# Group/Business/Corporation  Cash (Itemized)         1000.00
# NaN                         Cash (Non-Itemized)     1983.45
# dtype: float64

# %%
#what was the in-kind donation
cleanrossdf[cleanrossdf['ContributionType']=='In-Kind (Itemized)']
# Out:
#               FilingDate    Contributor        CityState ZipCode  \
# 114  4/1/2024 9:34:19 AM  JANE MCDONALD  UNION GROVE, AL   35175
#
#     ContributorType  Amount       ContributionDate    ContributionType  \
# 114      Individual  1040.0  3/28/2024 12:00:00 AM  In-Kind (Itemized)
#
#     Description RecipientName  ContributionID  RecipeintOrgID  ContSeqID  \
# 114         NaN    JEANA ROSS         1118446           31125     863634
#
#      MAXROWS  RecordCount
# 114    20000          395

# %%
#how much was the Alan Miller loan and when?
cleanmillerdf[cleanmillerdf['ContributionType'] == 'Loan']
# Out:
#               FilingDate  Contributor CityState ZipCode ContributorType  \
# 12  3/4/2024 11:14:59 PM  ALAN MILLER  ARAB, AL   35016      Individual
#
#     Amount       ContributionDate ContributionType Description  \
# 12  1250.0  2/24/2024 12:00:00 AM             Loan         NaN
#
#           RecipientName  ContributionID  RecipeintOrgID  ContSeqID  MAXROWS  \
# 12  ALAN CLIFTON MILLER         1114360           31117     860918    20000
#
#     RecordCount
# 12          674
